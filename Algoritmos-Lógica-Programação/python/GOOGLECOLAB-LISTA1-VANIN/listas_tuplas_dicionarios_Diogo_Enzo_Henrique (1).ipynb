# %% [markdown]
# Atividade Prática: Explorando Listas, Tuplas e Dicionários
#
# Objetivo: Criar, manipular e iterar sobre listas, tuplas e dicionários em Python.
#
# Criar as seguintes estruturas de dados:
# •Uma lista de cores favoritas.
# •Uma tupla de nomes de países.
# •Um dicionário de  informações  pessoais,  onde  as  chaves  são 'nome', 'idade'e 'cidade', escolha os valores a serem fornecidos.
#
# Manipulação das Estruturas de Dados:Realizar as seguintes operações em cada estrutura de dados:
# •Adicionar um novo elemento à lista de cores favoritas.
# •Modificar um elemento da tupla de nomes de países.
# •Adicionar uma nova entrada ao dicionário de informações pessoais.
# •Remover uma entrada do dicionário de informações pessoais.
#
# Iteração sobre os Elementos:Iterar sobre os elementos de cada estrutura de dados e exibir os resultados na tela. Usar um loop for para isso.
# •Para a lista de cores favoritas, imprimir cada cor em uma linha separada.•Para  a  tupla  de  nomes  de  países, imprimir  cada  país  em  uma  linha separada.
# •Para  o  dicionário  de  informações  pessoais, imprimir  cada  chave  e  seu respectivo valor em uma linha separada.

# %%
# Exercício - lista

print("CORES FAVORITAS\n")
print("Primeira Lista: ")
cores = ["Vermelho","Branco","Preto","Azul","Amarelo"]
print(cores)

cores.append("Laranja")
print("\nSegunda lista: ")
print(cores)

print("\nLista final de cores favoritas:\n")
for cor in cores:
  print(cor)
# Out:
# CORES FAVORITAS
#
# Primeira Lista:
# ['Vermelho', 'Branco', 'Preto', 'Azul', 'Amarelo']
#
# Segunda lista:
# ['Vermelho', 'Branco', 'Preto', 'Azul', 'Amarelo', 'Laranja']
#
# Lista final de cores favoritas:
#
# Vermelho
# Branco
# Preto
# Azul
# Amarelo
# Laranja

# %%
# Exercício - Tupla

print("PAÍSES QUE TEM COPA DO MUNDO\n")
print("Lista dos Campeões: ")
paises = ("Brasil","Itália","Alemanha","Argentina","França","Uruguai","Inglaterra","Portugal")
print(paises)

lista = list(paises)

print("\nLista correta dos Campeões: ")
lista[7] = "Espanha"
lista_correta = tuple(lista)
print(lista_correta)

print("\nCampeões do mundo:")
for pais in lista_correta:
  print(pais)
# Out:
# PAÍSES QUE TEM COPA DO MUNDO
#
# Lista dos Campeões:
# ('Brasil', 'Itália', 'Alemanha', 'Argentina', 'França', 'Uruguai', 'Inglaterra', 'Portugal')
#
# Lista correta dos Campeões:
# ('Brasil', 'Itália', 'Alemanha', 'Argentina', 'França', 'Uruguai', 'Inglaterra', 'Espanha')
#
# Campeões do mundo:
# Brasil
# Itália
# Alemanha
# Argentina
# França
# Uruguai
# Inglaterra
# Espanha

# %%
# Exercício - Diciónario

print("Dados Pessoais:")
pessoa = {"Nome": "Messi", "Idade": "36", "Cidade": "Rosário"}
print(pessoa)

pessoa["Profissão"] = "Jogador de Futebol"

del pessoa["Cidade"]

print("\nModificação:")
print(pessoa)

print("\nInformações Pessoais: ")
for chave, valor in pessoa.items():
  print(f"{chave}: {valor}")
# Out:
# Dados Pessoais:
# {'Nome': 'Messi', 'Idade': '36', 'Cidade': 'Rosário'}
#
# Modificação:
# {'Nome': 'Messi', 'Idade': '36', 'Profissão': 'Jogador de Futebol'}
#
# Informações Pessoais:
# Nome: Messi
# Idade: 36
# Profissão: Jogador de Futebol
